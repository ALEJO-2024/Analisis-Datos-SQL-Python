# %% [markdown]
# 1.	La Lista de Campeones (Listas): Crea una lista llamada campeones_mundial
# que contenga en formato de texto los 8 países que han ganado la Copa del Mundo de
# la FIFA (Brasil, Alemania, Italia, Argentina, Francia, Uruguay, Inglaterra, España).
# Imprime la lista.

# %%
list_campeones_mundiales = ['Brasil', 'Alemania', 'Italia', 'Argentina', 'Francia', 'Uruguay', 'Inglaterra', 'España']
print(list_campeones_mundiales)
# Out:
# ['Brasil', 'Alemania', 'Italia', 'Argentina', 'Francia', 'Uruguay', 'Inglaterra', 'España']

# %% [markdown]
# 2.	El Catálogo Musical (Diccionarios): Imagina que trabajas como analista de datos para Spotify. Crea un diccionario llamado cancion_top que contenga la información del track número 1 global. Debe tener las siguientes llaves: "titulo", "artista", "año_lanzamiento" y "reproducciones_millones". Imprime el diccionario.

# %%
cancion_top = {
    "titulo":"Blinding Lights", 
    "artista":"The Weeknd", 
    "año_lanzamiento":"2020",
    "reproducciones_millones":"5.500"
}

print(cancion_top)
# Out:
# {'titulo': 'Blinding Lights', 'artista': 'The Weeknd', 'año_lanzamiento': '2020', 'reproducciones_millones': '5.500'}

# %% [markdown]
# 3.	Coordenadas del Servidor (Tuplas): Tienes que guardar la latitud y longitud del centro de datos principal de la empresa (Ejemplo: 4.6097, -74.0817 para Bogotá). Guarda estos dos números decimales en una tupla llamada coordenadas_db e imprímela. (Recuerda: usamos tuplas porque este dato físico no puede cambiar).

# %%
Coordenadas_db = (4.6097, -74.0817)
print(f"las Coordenadas del centro de datos en Bogota son: {Coordenadas_db}")
# Out:
# las Coordenadas del centro de datos en Bogota son: (4.6097, -74.0817)

# %% [markdown]
# 4.	Limpieza de Etiquetas (Sets): Un error en el sistema guardó los géneros musicales de una lista de reproducción con registros duplicados: ["Rock", "Pop", "Rock", "Jazz", "Pop", "Salsa","Pop", "Salsa"]. Crea esta lista, conviértela en un Set llamado generos_unicos para eliminar los duplicados, e imprímela.

# %%
generos_unicos = {"Rock", "Pop", "Rock", "Jazz", "Pop", "Salsa","Pop", "Salsa"}
print(generos_unicos)
# Out:
# {'Jazz', 'Salsa', 'Pop', 'Rock'}

# %% [markdown]
# El Laboratorio de Transformación (Manipulación de Listas)
# Eres el encargado del inventario en un e-commerce. Tienes la siguiente lista inicial de productos más vendidos hoy: inventario = ["Laptop", "Monitor", "Teclado", "Mouse"]
# Escribe el código paso a paso para realizar las siguientes transformaciones, imprimiendo la lista final al terminar todo el proceso:
# 1.	Añade unos "Audifonos" al final del inventario.
# 2.	Inserta una "Tablet" exactamente en la segunda posición de la lista (índice 1)

# %%
inventario = ["Laptop", "Monitor", "Teclado", "Mouse"]

inventario.append('Audifonos')
inventario[1]='Tablet'

print(inventario)
# Out:
# ['Laptop', 'Tablet', 'Teclado', 'Mouse', 'Audifonos']

# %% [markdown]
# 3.	Borra el "Teclado" porque se agotó el stock usando el método que busca por nombre.

# %%
inventario.remove('Teclado')
print(inventario)
# Out:
# ['Laptop', 'Tablet', 'Mouse', 'Audifonos']

# %% [markdown]
# 4.	Saca el último elemento de la lista (para enviarlo a bodega) usando el método correspondiente y guárdalo en una variable llamada producto_enviado.

# %%
producto_envidado = inventario[-1]
print(producto_envidado)
# Out:
# Audifonos

# %%
inventario.remove('Audifonos')
print(inventario)
# Out:
# ['Laptop', 'Tablet', 'Mouse']

# %% [markdown]
# 5.	Ordena el inventario restante alfabéticamente (de la A a la Z).

# %%
inventario.sort()
print(inventario)
# Out:
# ['Laptop', 'Mouse', 'Tablet']

# %% [markdown]
# 6.	Dale vuelta a la lista para verla en orden Z a A.

# %%
inventario.reverse()
print(inventario)
# Out:
# ['Tablet', 'Mouse', 'Laptop']
